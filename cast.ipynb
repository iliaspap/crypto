# %%
import numpy as np
import random
import pickle

# Reading ballots
s = []
with open('ballots', 'rb') as fb:
    s = pickle.load(fb)

# Recovering n and m    
n = len(s)
(_, temp, _) = s[0]
m = len(temp)

# Simulating coin flip for all n voters
a = format(random.getrandbits(n), 'b')

# Simulating random vote for each voter. vote[i][j] is the j-th vote of the i-th voter
vote = [np.random.permutation(m) for i in range(n)]

# Making list containing all votes in the form (tag, side, [vote_codes])
allVotes = []
for i in range(n):
    (tag, s0, s1) = s[i]
    if a[i] == '0':
        C = []
        for j in range(m):
            (name, code) = s0[vote[i][j]]
            C.append(code)
        allVotes.append((tag, 0, C))
    if a[i] == '1':
        C = []
        for j in range(m):
            (name, code) = s1[vote[i][j]]
            C.append(code)
        allVotes.append((tag, 1, C))

print(allVotes)
        
with open('votes', 'wb') as fv:
    pickle.dump(allVotes, fv)
# Out:
# [(1, 1, ['14', '13', '16', '15']), (2, 0, ['17', '20', '18', '19']), (3, 0, ['27', '28', '26', '25']), (4, 0, ['35', '34', '33', '36']), (5, 0, ['42', '41', '44', '43']), (6, 0, ['52', '49', '51', '50']), (7, 0, ['60', '58', '59', '57']), (8, 0, ['68', '66', '65', '67']), (9, 1, ['80', '78', '77', '79']), (10, 1, ['88', '86', '85', '87']), (11, 0, ['89', '90', '92', '91']), (12, 1, ['104', '101', '103', '102']), (13, 0, ['105', '107', '106', '108']), (14, 1, ['117', '118', '119', '120']), (15, 0, ['124', '122', '121', '123']), (16, 1, ['136', '135', '134', '133']), (17, 0, ['138', '140', '139', '137']), (18, 1, ['150', '152', '149', '151']), (19, 1, ['157', '159', '160', '158']), (20, 1, ['166', '168', '165', '167']), (21, 1, ['175', '176', '173', '174']), (22, 0, ['177', '180', '179', '178']), (23, 1, ['191', '192', '189', '190']), (24, 1, ['198', '200', '197', '199']), (25, 0, ['202', '201', '203', '204']), (26, 0, ['210', '211', '209', '212']), (27, 0, ['217', '220', '219', '218']), (28, 1, ['230', '229', '232', '231']), (29, 1, ['238', '237', '239', '240']), (30, 0, ['244', '242', '243', '241']), (31, 1, ['254', '255', '253', '256']), (32, 0, ['259', '257', '260', '258']), (33, 0, ['267', '268', '266', '265']), (34, 0, ['276', '274', '273', '275']), (35, 0, ['284', '281', '283', '282']), (36, 1, ['293', '296', '295', '294']), (37, 1, ['303', '302', '301', '304']), (38, 0, ['305', '306', '307', '308']), (39, 1, ['319', '320', '318', '317']), (40